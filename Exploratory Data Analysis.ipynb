# %% [markdown]
# # Explanatory Data Analysis
#
# Task- 3
# Submitted by- Ranita Ghosh

# %%
conda install seaborn
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data_set=pd.read_csv("/Users/ranitaghosh/Desktop/SampleSuperstore.csv")
data_set
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data_set.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
sns.set_style("whitegrid")
sns.pairplot(data_set,hue="Region",palette='bwr')

# %%
data_set['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
segment=data_set.Segment.value_counts().reset_index()
segment.columns=("Segment","Count")
segment
# Out:
#        Segment  Count
# 0     Consumer   5191
# 1    Corporate   3020
# 2  Home Office   1783

# %%
plt.pie(x="Count",labels="Segment",data=segment,radius=3,autopct="%.2f",pctdistance=0.4)
# Out:
# ([<matplotlib.patches.Wedge at 0x11c6135b0>,
# ...
#  [Text(-0.20112055070046053, 3.293865589863367, 'Consumer'),
#   Text(-1.5806529869448442, -2.8968148257806097, 'Corporate'),
#   Text(2.795095858676503, -1.754263133286869, 'Home Office')],
#  [Text(-0.07313474570925838, 1.1977693054048606, '51.94'),
#   Text(-0.5747829043435798, -1.0533872093747672, '30.22'),
#   Text(1.016398494064183, -0.6379138666497706, '17.84')])

# %%
plt.figure(figsize=(9,5))
plt.title('CATEGORIES VS REGION')
sns.countplot(x=data_set['Category'],hue=data_set['Region'],palette='rocket')
plt.xticks()
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Furniture'),
#   Text(1, 0, 'Office Supplies'),
#   Text(2, 0, 'Technology')])

# %%
high_sale=data_set[data_set["Sales"]>3000]
high_sale.head()
# Out:
#           Ship Mode      Segment        Country           City         State  \
# 27   Standard Class     Consumer  United States   Philadelphia  Pennsylvania
# 165  Standard Class     Consumer  United States    San Antonio         Texas
# 251  Standard Class     Consumer  United States      San Diego    California
# 262    Second Class    Corporate  United States        Houston         Texas
# 318  Standard Class  Home Office  United States  New York City      New York
#
#      Postal Code   Region    Category Sub-Category     Sales  Quantity  \
# 27         19140     East   Furniture    Bookcases  3083.430         7
# 165        78207  Central  Technology     Machines  8159.952         8
# 251        92037     West  Technology  Accessories  3347.370        13
# 262        77036  Central  Technology     Machines  3059.982         3
# 318        10024     East  Technology     Machines  3991.980         2
#
#      Discount     Profit
# 27        0.5 -1665.0522
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=high_sale["Sales"],y=high_sale["State"],data=data_set)
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='State'>

# %%
data_set.Sales.max()
# Out:
# 22638.48

# %%
data_set.Sales.min()
# Out:
# 0.444

# %%
plt.figure(figsize=(9,5))
low_sale=data_set[data_set["Sales"]<1]
sns.barplot(y=low_sale["State"],x=low_sale["Sales"],data=low_sale,palette='rocket')
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='State'>

# %%
low_profit=data_set[data_set["Profit"]<1]
low_profit.head()
# Out:
#          Ship Mode      Segment        Country             City         State  \
# 3   Standard Class     Consumer  United States  Fort Lauderdale       Florida
# 14  Standard Class  Home Office  United States       Fort Worth         Texas
# 15  Standard Class  Home Office  United States       Fort Worth         Texas
# 23    Second Class     Consumer  United States     Philadelphia  Pennsylvania
# 27  Standard Class     Consumer  United States     Philadelphia  Pennsylvania
#
#     Postal Code   Region         Category Sub-Category      Sales  Quantity  \
# 3         33311    South        Furniture       Tables   957.5775         5
# 14        76106  Central  Office Supplies   Appliances    68.8100         5
# 15        76106  Central  Office Supplies      Binders     2.5440         3
# 23        19140     East        Furniture       Chairs    71.3720         2
# 27        19140     East        Furniture    Bookcases  3083.4300         7
#
#     Discount     Profit
# ...

# %%
data=['Sales','Quantity','Discount','Profit']
plt.figure(figsize=(9,5))
sns.heatmap(data_set[data].corr(),annot=True )
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Thanks for watching :)
